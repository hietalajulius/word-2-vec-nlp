# %%
from gensim.test.utils import datapath
from gensim import utils
import pandas as pd
import gensim.models

class TweetCorpus(object):
    """An interator that yields sentences (lists of str)."""
            
    def __iter__(self, filename="data/processed_train.csv"):
        df = pd.read_csv(filename)
        total_words = 0
        for i in range(len(df)):
            line = str(df['text'][i])
            split = line.split()
            preprocessed = utils.simple_preprocess(line)
            total_words += len(split)
            print("preprocessed",preprocessed)
            yield preprocessed
        #print("Total words:", total_words)
sentences = TweetCorpus()
model = gensim.models.Word2Vec(sentences=sentences, window=10, iter=1, size=300, min_count=1, sg=0)
# Out:
# preprocessed ['blahhhhhh', 'lt', 'lt', 'lt', 'lt', 'thats', 'feel', 'today']
# preprocessed ['happy', 'birthday']
# preprocessed ['nerale', 'hannu', 'donno', 'called', 'english', 'kinda', 'dark', 'magenta', 'small', 'sized', 'fruit', 'tongue', 'turns', 'color']
# preprocessed ['know', 'suicide', 'stick', 'men', 'square', 'shapes']
# preprocessed ['sad', 'toooo', 'hope', 'contract', 'show', 'work', 'things']
# preprocessed ['okay', 'faceoffmusic', 'wait']
# preprocessed ['good', 'luck', 'run']
# preprocessed ['uhh', 'hate', 'hospital']
# preprocessed ['okay', 'decide', 'really', 'ugly', 'really', 'nice', 'think', 'want', 'anyway', 'feel', 'outfit', 'coming', 'ha']
# preprocessed ['housework', 'nice', 'day', 'wahh']
# preprocessed ['anti', 'ben', 'sorry', 'guys', 'eyes', 'nose', 'started', 'going', 'crazy', 'right', 'stepped', 'outside', 'bring', 'blankets']
# preprocessed ['looking', 'like', 'getting', 'teeny', 'pay', 'rise', 'year']
# preprocessed ['josh', 'turner', 'amazingness', 'tony', 'makin', 'night', 'complete', 'gonna', 'get', 'flown', 'ny', 'free', 'compete', 'uhh']
# preprocessed ['hahha', 'thats', 'great', 'defines', 'love']
# preprocessed ['good', 'morning', 'brand', 'new', 'day', 'ready', 'make', 'life', 'better']
# preprocessed ['hey', 'toby', 'miss', 'france', 'hope', 'shall', 'see', 'soon', 'love', 'rock', 'guys']
# preprocessed ['sleep', 'way', 'top', 'thank', 'voiceing', 'hollywood', 'non', 'actors', 'truly', 'needed', 'hear']
# preprocessed ['good', 'luckkk', 'girll', 'win', 'im', 'positive', 'everybody', 'voted', 'like', 'million', 'times', 'love']
# preprocessed ['love', 'though', 'still', 'need', 'see', 'fantastic', 'hair', 'long']
# preprocessed ['okay', 'need', 'rest', 'tomorrow', 'whoa', 'whoa', 'wish', 'luck', 'guys']
# preprocessed ['send', 'direct', 'message', 'following', 'person', 'person', 'following']
# preprocessed ['still', 'sad', 'max', 'longer', 'sytycd', 'sigh']
# preprocessed ['omg', 'allison', 'lost', 'americas', 'next', 'top', 'models', 'sad']
# preprocessed ['self', 'deprecation']
# preprocessed ['setting', 'network']
# preprocessed ['italian', 'pizza', 'neighbor', 'restaurant', 'hmm']
# preprocessed ['sorry', 'ruined', 'morning', 'relieved', 'captain', 'spock', 'also', 'dating', 'lame', 'hills', 'star']
# preprocessed ['stressed', 'today', 'fantasy', 'survive']
# preprocessed ['love', 'city', 'hope', 'move', 'one', 'day', 'miss', 'family', 'friends', 'beantown']
# preprocessed ['dinner', 'abish', 'frankie']
# preprocessed ['believe', 'quot', 'busy', 'quot', 'talk']
# preprocessed ['still', 'eating', 'badass', 'burgers']
# preprocessed ['vibin', 'crib', 'cooka', 'waiting', 'platano']
# preprocessed ['bugs', 'eh', 'better', 'stay', 'away', 'story', 'quot', 'parasite', 'quot']
# preprocessed ['glad', 'good', 'time', 'girl']
# preprocessed ['ok', 'cmnted', 'tom']
# preprocessed ['work', 'home', 'tonight']
# preprocessed ['great', 'must', 'also', 'pumped']
# preprocessed ['awesome', 'thanks']
# preprocessed ['son', 'greatest', 'man', 'ever', 'lived']
# preprocessed ['sleep', 'evadin', 'moment', 'next', 'post', 'incubus', 'cure', 'franz', 'ferdinand', 'sarah', 'mclachlan']
# preprocessed ['app', 'review']
# preprocessed ['bed', 'urgh', 'would', 'love', 'go', 'home']
# preprocessed ['thank', 'congrats', 'amp', 'really', 'special', 'night']
# preprocessed ['birthday', 'write', 'mail', 'strange', 'talkz']
# preprocessed ['love', 'watching', 'reruns', 'oc']
# preprocessed ['hi', 'mareyn']
# preprocessed ['happy', 'mothers', 'day', 'mothers']
# preprocessed ['party', 'fine']
# preprocessed ['guttered', 'ruby', 'got', 'eliminated', 'nzntm', 'supporting', 'locals', 'haha', 'hosanna', 'better', 'win']
# preprocessed ['hear', 'thunder', 'somebody', 'called', 'woken']
# preprocessed ['thanks', 'followfriday', 'recommendation']
# preprocessed ['party', 'tonight', 'daredevil', 'costume']
# preprocessed ['lol', 'tying', 'em', 'gagging', 'em', 'would', 'cheaper', 'love']
# preprocessed ['bro', 'stole', 'big', 'bag', 'pink', 'bag', 'gone', 'means', 'gta', 'use', 'tiny', 'schbag', 'bad', 'bec', 'cant', 'bring', 'whole', 'wardrobe']
# preprocessed ['oh', 'dear', 'went', 'early']
# preprocessed ['justinnauman', 'sorry', 'guys', 'time', 'got', 'ice', 'cream', 'would', 'melted']
# preprocessed ['nan']
# preprocessed ['wow', 'dont', 'think', 'ive', 'seen', 'world', 'time', 'sunday', 'liking', 'see']
# preprocessed ['heading', 'churchhh']
# preprocessed ['en', 'route', 'banfield', 'let', 'positive', 'today', 'practice', 'love', 'lym', 'antonio']
# preprocessed ['lean', 'strong', 'ile', 'friend', 'oh', 'camp']
# preprocessed ['almost', 'forget', 'portuguese', 'test', 'know', 'nothing']
# preprocessed ['ipod', 'dont', 'mcfly', 'hsm', 'got', 'new', 'songs']
# preprocessed ['tired', 'drive', 'friend', 'work', 'goin']
# preprocessed ['feeling', 'great']
# preprocessed ['summer', 'started', 'going', 'good', 'far', 'cant', 'wait', 'go', 'tonight', 'really', 'need', 'chill', 'new', 'yorkers']
# preprocessed ['camp', 'missing', 'derby', 'ehh', 'haircut', 'disappontment']
# preprocessed ['yes', 'meant', 'got', 'rejected', 'north', 'denver', 'evidently', 'far', 'north', 'looking', 'another', 'group']
# preprocessed ['still', 'waiting', 'venkman', 'stantz', 'shirts', 'ship', 'two', 'weeks', 'guess', 'ran']
# preprocessed ['bored', 'countdown', 'hours', 'work']
# preprocessed ['race', 'life', 'today', 'minutes', 'scotty', 'tore', 'track', 'wharty', 'bum', 'though', 'lol']
# preprocessed ['watching', 'national', 'spelling', 'bee']
# preprocessed ['sure', 'dm', 'coming', 'way']
# preprocessed ['miss', 'kiss', 'kate', 'also', 'kind', 'miss', 'little', 'mary', 'sunshine']
# preprocessed ['sad', 'wheress', 'nickjonas', 'guys', 'need', 'meeet', 'love']
# preprocessed ['legs', 'hurting', 'standing', 'day']
# preprocessed ['sim', 'blake', 'sim', 'thriller', 'dance', 'classical', 'music', 'laugh']
# preprocessed ['use', 'dd', 'facility', 'hv', 'ur', 'online', 'banking', 'net', 'ironically', 'connected', 'banks', 'online', 'payments']
# preprocessed ['tellin', 'weather', 'man']
# preprocessed ['gettin', 'dressed', 'knows']
# preprocessed ['um', 'supposed']
# preprocessed ['give', 'second']
# preprocessed ['great', 'mood', 'going', 'spread', 'job', 'around', 'positive', 'love', 'hate', 'peace', 'positivity']
# preprocessed ['love', 'csi', 'miami', 'supposedly', 'serious', 'show', 'funniest', 'show', 'television', 'garretjiroux']
# preprocessed ['way', 'get']
# preprocessed ['hehehe', 'figured', 'since', 'roblef', 'organized', 'play', 'clan']
# preprocessed ['believed', 'second']
# preprocessed ['lol', 'bored', 'today', 'good', 'lol', 'apart', 'mock', 'exam', 'liked', 'thing', 'lol']
# preprocessed ['fandom', 'crack', 'fics', 'ftw', 'lmfao', 'dinner', 'minutes', 'blah', 'maybe', 'study', 'thing', 'lt', 'lt']
# preprocessed ['one', 'day', 'school', 'left', 'ohh', 'getting', 'license', 'today']
# preprocessed ['uhh', 'got', 'rumbly', 'tumbly']
# preprocessed ['half', 'day', 'todaaaaaay', 'field', 'day', 'jessica', 'crib', 'afterrrrr', 'bye']
# preprocessed ['losing', 'followers', 'every', 'minute', 'happening']
# preprocessed ['sounds', 'worse', 'sultana', 'bran']
# preprocessed ['also', 'characters', 'nothing', 'justice', 'least', 'album']
# preprocessed ['watching', 'peep', 'show', 'finished', 'cleaning', 'gaff', 'really', 'nice', 'day', 'hope', 'everyone', 'enjoying']
# preprocessed ['ditto', 'tried', 'something', 'new', 'honor', 'liked', 'cranlimeaide', 'bunch', 'tr', 'yummy']
# preprocessed ['says', 'isnt', 'myspace', 'working']
# preprocessed ['want', 'sum', 'guacamole', 'chips', 'breakfast', 'sad']
# preprocessed ['watching', 'bit', 'night', 'museum', 'going', 'sleep', 'hooray', 'days']
# preprocessed ['made', 'new', 'video', 'audrey']
# preprocessed ['im', 'seeing', 'greenday', 'twice', 'florida', 'work', 'disney', 'super', 'bummed', 'dont', 'see', 'hometown', 'boston', 'tho']
# preprocessed ['least', 'got', 'dress', 'got', 'like', 'earrings', 'mossie']
# preprocessed ['lol', 'definatly', 'breakfast', 'champions']
# preprocessed ['aww', 'seconds', 'new', 'moon', 'like', 'pure', 'bliss']
# preprocessed ['thats', 'twitter', 'brings', 'boredom', 'listen', 'filth', 'usually', 'works']
# preprocessed ['like', 'laugh', 'follow', 'simple']
# preprocessed ['hpe', 'relax']
# preprocessed ['day', 'done', 'far', 'good', 'got', 'get', 'used', 'standing', 'scratch']
# preprocessed ['bored', 'reading', 'would', 'like', 'usb', 'port', 'head', 'upload', 'tried', 'shoving', 'memory', 'stick', 'nose', 'seem', 'work']
# preprocessed ['newest', 'follower', 'looks', 'good', 'behind', 'ikki', 'oo', 'followfriday']
# preprocessed ['talked', 'zomg', 'economy', 'money', 'sigh', 'ah', 'well', 'ps', 'read']
# preprocessed ['seriously', 'need', 'pick', 'spock', 'beard', 'none', 'sad', 'panda']
# preprocessed ['tried', 'call', 'miss', 'marc', 'eee']
# preprocessed ['cousins', 'communion', 'party']
# preprocessed ['come', 'darkside']
# preprocessed ['study', 'study', 'study', 'history', 'biology', 'sucks', 'die', 'bie', 'twit']
# preprocessed ['must', 'friday', 'somewhere', 'thanks', 'much', 'ff']
# preprocessed ['haha', 'oh', 'trust', 'hills', 'killed', 'ton', 'calories', 'morning', 'meaning', 'eat', 'want', 'tonight', 'woot']
# preprocessed ['watching', 'china', 'gp', 'tv', 'kimi', 'shanghai', 'hometown', 'rainy', 'rainy', 'race']
# preprocessed ['help', 'need', 'switch', 'cheery', 'neal', 'shoulder', 'aches', 'back', 'work', 'gorgeous', 'day', 'outside', 'office', 'untill']
# preprocessed ['want', 'stop', 'stop']
# preprocessed ['ooh', 'ginger', 'already', 'mentally', 'flappy', 'hands', 'would', 'physicist', 'sigh']
# preprocessed ['yes', 'haha', 'southern', 'indiana', 'want', 'simple', 'life']
# preprocessed ['know', 'going', 'say', 'goodbye']
# preprocessed ['hey', 'lulz', 'always', 'serious']
# preprocessed ['great', 'time', 'celebrating', 'engagement', 'ajwatson', 'jilllancaster', 'bed', 'time']
# preprocessed ['text', 'work', 'times', 'trying', 'send']
# preprocessed ['lion', 'lamb', 'love', 'gallery', 'everglow', 'com', 'two', 'favourites', 'rob', 'photo']
# preprocessed ['well', 'work']
# preprocessed ['yay', 'time', 'low', 'love', 'fun']
# preprocessed ['waiting', 'dave', 'call', 'washing', 'swollen', 'red', 'eyes']
# preprocessed ['ordering', 'pizza', 'randi']
# preprocessed ['goodnight', 'twitterverse']
# preprocessed ['still', 'miss']
# preprocessed ['orange', 'happy', 'colour', 'moment', 'love', 'orange', 'nails', 'today']
# preprocessed ['miss']
# preprocessed ['sore', 'throat', 'headache', 'typical']
# preprocessed ['aww', 'dog', 'seizure']
# preprocessed ['awesome', 'keep', 'good', 'work', 'feel', 'free', 'follow', 'like']
# preprocessed ['enjoying', 'wifi', 'walk', 'back', 'home', 'internet']
# preprocessed ['first', 'headline', 'google', 'feed', 'terrible']
# preprocessed ['coco', 'happy']
# preprocessed ['took', 'shower', 'soon', 'cinema', 'watch', 'hmtm']
# preprocessed ['tried', 'get', 'pic', 'bebo', 'group', 'called', 'scene', 'teenz', 'didnt', 'put']
# preprocessed ['drove', 'olive', 'garden', 'nwlynch']
# preprocessed ['going', 'bowling', 'excited']
# preprocessed ['dumbass', 'went', 'look', 'online', 'somebody', 'said', 'quot', 'hate', 'claudine', 'quot', 'summerland', 'quot', 'nooo']
# preprocessed ['veeverdone', 'cops', 'come', 'bust', 'ca', 'great', 'smoke', 'im', 'sitting', 'apound', 'good']
# preprocessed ['welcome']
# preprocessed ['forget', 'nooks', 'crannies']
# preprocessed ['people', 'hoped', 'fence', 'got']
# preprocessed ['feeeeeeeeeeeet', 'hurt']
# preprocessed ['reach', 'finnish', 'friend']
# preprocessed ['urgh', 'two', 'moore', 'finals', 'todaaay', 'suuucks']
# preprocessed ['yay', 'twitter', 'back']
# preprocessed ['oh', 'boy', 'food', 'amazing', 'feeling', 'better', 'already']
# preprocessed ['think', 'deep', 'think', 'weird', 'narcissistic', 'sorry']
# preprocessed ['music', 'school', 'afternoon']
# preprocessed ['time', 'chico', 'time', 'sorry', 'carry']
# preprocessed ['whew', 'end', 'lunch', 'break', 'still', 'sleepy']
# preprocessed ['lol', 'except', 'would', 'tweeting', 'iphone']
# preprocessed ['ten', 'days', 'left', 'whaaa']
# preprocessed ['love', 'going', 'services', 'great', 'way', 'start', 'sunday']
# preprocessed ['teatime']
# preprocessed ['memorial', 'mine', 'miss', 'iphone']
# preprocessed ['remember', 'thing', 'bad', 'kids', 'bad', 'parenting']
# preprocessed ['wish', 'straw', 'would', 'talk']
# preprocessed ['last', 'two', 'day', 'giro']
# preprocessed ['agreed', 'twitter', 'acct', 'social', 'media', 'expert', 'days', 'min', 'locked', 'room', 'screams', 'real']
# preprocessed ['non', 'stop', 'rain', 'day', 'today']
# preprocessed ['check', 'creepy', 'ghost', 'sightings', 'feel', 'free', 'tweet']
# preprocessed ['please', 'tell', 'went', 'see', 'baby', 'lemur', 'weekend']
# preprocessed ['noooooo', 'closed', 'noooooo', 'chocolate']
# preprocessed ['finished', 'highschool', 'forever']
# preprocessed ['sent', 'flip', 'mino', 'back']
# preprocessed ['crazy', 'day', 'coming']
# preprocessed ['wzersz', 'wat', 'ur', 'ppl', 'havin', 'grl', 'slavin', 'fa', 'real', 'kn', 'president', 'isz', 'black']
# preprocessed ['sometimes', 'walking', 'brooklyn', 'really', 'makes', 'miss', 'columbus']
# preprocessed ['science', 'homework', 'harder', 'sheet', 'harder', 'atm']
# preprocessed ['woo', 'speaking', 'devil', 'back']
# preprocessed ['sick', 'ya', 'thats', 'mia']
# preprocessed ['thank']
# preprocessed ['really', 'bad', 'night', 'sleep', 'believe', 'eminem', 'walked', 'mtv', 'awards', 'spose', 'ass', 'face']
# preprocessed ['things', 'hard', 'moment', 'sure', 'deal', 'hope', 'things', 'turn', 'right', 'end']
# preprocessed ['leaving', 'houston', 'tour', 'starts', 'gone', 'til', 'aug', 'st']
# preprocessed ['layin', 'tha', 'bed', 'pain']
# preprocessed ['well', 'working', 'boring', 'barely', 'anyone', 'came', 'maybe', 'every', 'freakin', 'person', 'went', 'ripe', 'bummed']
# preprocessed ['make', 'fete', 'de', 'la', 'musique']
# preprocessed ['mean', 'seem', 'insensitive', 'risky', 'also', 'good', 'bath', 'relaxing', 'properties', 'imagine']
# preprocessed ['oh', 'know', 'option', 'add', 'thought', 'trying', 'something', 'else']
# preprocessed ['goodbye', 'freedom']
# preprocessed ['ca', 'dechire', 'fringe', 'tu', 'matter', 'knight', 'rider']
# preprocessed ['way', 'late', 'working', 'pet', 'project', 'mozilla', 'learned', 'things', 'forgot', 'trigonometry', 'array', 'foreach', 'array']
# preprocessed ['geography', 'exam', 'soooon', 'dreading', 'ittt']
# preprocessed ['homework', 'way', 'am']
# preprocessed ['velveetahead', 'glad', 'survived', 'night', 'hope', 'durnic', 'surviving', 'morning', 'speedy', 'recovery']
# preprocessed ['thanks', 'info', 'free', 'conference', 'asking', 'boss', 'go']
# preprocessed ['cleaning', 'weight', 'room', 'dad']
# preprocessed ['hate', 'waking', 'bad', 'news', 'really', 'fucks', 'mood']
# preprocessed ['excuse', 'mr', 'criss', 'angel', 'awsomeist', 'guy', 'everrr', 'im', 'luxor', 'really', 'wanna', 'get', 'picture']
# preprocessed ['mynervouscharm', 'littlebirds', 'sonsah', 'hope', 'happy', 'mothers', 'day']
# preprocessed ['watching', 'changeling', 'well', 'sort', 'like', 'nasty', 'bits', 'go', 'look', 'restaurant', 'city', 'listen']
# preprocessed ['crazy', 'like', 'comes', 'nowhere', 'daytime', 'everything']
# preprocessed ['trying', 'break', 'sugar', 'addiction', 'hard', 'great', 'making', 'amp', 'sampling', 'brothers', 'grooms', 'cake', 'set', 'back']
# preprocessed ['deciding', 'wear', 'oasis', 'sat', 'think', 'going', 'rain']
# preprocessed ['hi', 'great', 'day']
# preprocessed ['moving', 'day', 'wont', 'internet', 'sorry', 'updates']
# preprocessed ['welcome', 'twitter', 'family', 'know', 'saw', 'shoot', 'today', 'good', 'ass', 'memory', 'lol']
# preprocessed ['happy', 'diversity', 'one', 'bgt', 'tbh', 'everyone', 'else', 'amazing', 'aswell']
# preprocessed ['car', 'officially', 'dead', 'rip', 'nancy']
# preprocessed ['get', 'followers', 'day', 'using', 'www', 'tweeterfollow', 'com', 'add', 'everyone', 'train', 'pay', 'vip']
# preprocessed ['diembrown', 'lot', 'interwsting', 'tweets', 'today', 'thank', 'let', 'knowing', 'great', 'time', 'dolls']
# preprocessed ['nice', 'although', 'orion', 'would', 'constellation', 'donned', 'flip', 'flops', 'sat', 'outside', 'sunsoaking']
# preprocessed ['friend', 'meet', 'go', 'xo']
# preprocessed ['hair', 'app', 'made', 'trip', 'back', 'wait', 'see', 'east', 'coast', 'home', 'since', 'december']
# preprocessed ['seans', 'happy', 'beach', 'time']
# preprocessed ['raining']
# preprocessed ['sad', 'japanese', 'song', 'ehe', 'ehe', 'ehe', 'crying', 'sound', 'loveless', 'attacking', 'drama', 'anime', 'awesome', 'old', 'animes', 'awesome']
# preprocessed ['blessed', 'trapped', 'xico', 'city', 'dreaming', 'retiring', 'day', 'vancouver', 'victoria', 'enjoy']
# preprocessed ['think', 'start', 'loving', 'friendfeed']
# preprocessed ['amazon', 'know', 'order', 'books', 'amazon', 'try', 'hehe']
# preprocessed ['thanks', 'karla', 'hope', 'come', 'back', 'soon']
# preprocessed ['also', 'got', 'parking', 'ticket']
# preprocessed ['happy', 'birthday', 'tamiekabiffin', 'umm', 'much', 'birthday', 'yesterday', 'yaye', 'kids', 'sick', 'today', 'hope', 'feel', 'better', 'soon']
# preprocessed ['want', 'gene', 'simmons', 'kid', 'nick', 'ad', 'sophie', 'lucky']
# preprocessed ['actually', 'good', 'tech', 'rehearsal', 'dinner', 'nick', 'joel']
# preprocessed ['going', 'see', 'noon']
# preprocessed ['sucks']
# preprocessed ['feature', 'iphone', 'gs']
# preprocessed ['kaaaaaaty', 'love', 'songs']
# preprocessed ['oh', 'see', 'photo', 'put', 'mr', 'whippy']
# preprocessed ['thanks']
# preprocessed ['wish']
# preprocessed ['way', 'go', 'dad', 'gonna', 'dad', 'billionth', 'time', 'hope', 'time', 'get', 'right']
# preprocessed ['gotta', 'love', 'ebay', 'sell', 'collectibles']
# preprocessed ['didnt', 'watch', 'tonight', 'forgot']
# preprocessed ['idont', 'wanna', 'work']
# preprocessed ['check', 'date', 'free']
# preprocessed ['hi', 'waiting', 'bus', 'right', 'rainy', 'sad']
# preprocessed ['tbh', 'even', 'think', 'broken', 'stuck', 'probs', 'send', 'bill', 'anyway']
# preprocessed ['wish', 'miss']
# preprocessed ['went', 'pre', 'school', 'today', 'niece', 'quot', 'dads', 'donuts', 'quot', 'dad', 'work', 'asked', 'go', 'kids', 'liked']
# preprocessed ['hi', 'tom', 'tomorrow', 'last', 'day', 'school', 'yayy', 'food', 'fight', 'school', 'today', 'got', 'apple', 'jucie', 'ever']
# preprocessed ['thank', 'rainfall', 'hopefully', 'tomorrow', 'space']
# preprocessed ['marvin', 'shud', 'play', 'house', 'persian', 'cat']
# preprocessed ['screw', 'goin', 'back', 'bed', 'ill', 'go', 'tomorrow', 'kinda', 'sad']
# preprocessed ['called', 'mom', 'wish', 'happy', 'mothers', 'day', 'said', 'wasnt', 'good', 'time', 'go']
# preprocessed ['want', 'mexican', 'drug', 'kingpin', 'dude', 'like', 'nancy', 'end', 'weeds', 'probably', 'kept']
# preprocessed ['fun', 'listening', 'ginoandfran', 'radio', 'kids', 'danielle', 'im', 'going', 'bed', 'na', 'almost', 'am', 'na', 'nyt', 'guys']
# preprocessed ['woken']
# preprocessed ['nice', 'little', 'figurine', 'yotsuba', 'dan', 'thought', 'belonged', 'well', 'longer']
# preprocessed ['going', 'bed', 'awful', 'day']
# preprocessed ['clean']
# preprocessed ['right', 'dj', 'ing', 'rain', 'happy', 'bunny', 'grrrr']
# preprocessed ['sonny', 'chance', 'funny']
# preprocessed ['think', 'latter', 'xd', 'lol', 'getting', 'ready', 'school', 'xx']
# preprocessed ['assuming', 'since', 'respond', 'assume', 'died', 'shawna']
# preprocessed ['love']
# preprocessed ['nothing', 'much', 'getting', 'sleepy']
# preprocessed ['confusion', 'stress', 'eating', 'face', 'someone', 'pick', 'streaming', 'movie', 'netflix', 'entertaining', 'thanks', 'anything']
# preprocessed ['luving', 'purchases', 'tday', 'missing', 'craig', 'luving', 'bgt']
# preprocessed ['inspired', 'article', 'google', 'small', 'business', 'network', 'question', 'day']
# preprocessed ['yayyy', 'glad', 'liked']
# preprocessed ['like', 'family']
# preprocessed ['got', 'back', 'grocery', 'shopping', 'moon', 'sliver', 'venus', 'bright', 'sky', 'lightening', 'beautiful']
# preprocessed ['working', 'today', 'raining', 'even', 'go', 'walk']
# preprocessed ['alanis', 'morissette', 'ftw', 'time', 'favourite', 'artist']
# preprocessed ['neither', 'much', 'fun']
# preprocessed ['miami', 'nd', 'home', 'wish', 'weather', 'would', 'get', 'better']
# preprocessed ['thanks', 'tori', 'maybe', 'go', 'next', 'time', 'hopefully', 'tomorrow']
# preprocessed ['would', 'google', 'problem', 'solving', 'made', 'easy', 'yes', 'read', 'though', 'lol']
# preprocessed ['haha', 'know', 'never', 'end', 'keep', 'saying', 'stuff', 'haha', 'know', 'loove', 'haha', 'yeah', 'sarah', 'great']
# preprocessed ['thinks', 'tonight', 'good']
# preprocessed ['get', 'pjs', 'morning']
# preprocessed ['takens', 'good', 'movie', 'vchat', 'miss', 'macbook']
# preprocessed ['wetsuits', 'wetsuits', 'art', 'thou', 'wetsuits', 'ooooohh', 'doin', 'job', 'getting', 'wet', 'keeping', 'bodies', 'warm']
# preprocessed ['ew', 'raining']
# preprocessed ['saw', 'gatorade', 'commercial', 'loved']
# preprocessed ['waiting', 'advil', 'pm', 'knock', 'super', 'early', 'get']
# preprocessed ['right', 'common', 'cold', 'got', 'one', 'date', 'tomorrow', 'good', 'mix']
# preprocessed ['crap', 'must', 'love', 'put', 'much', 'salt', 'incredible', 'dough', 'slaved', 'oh', 'well']
# preprocessed ['jaw', 'line', 'waiting', 'neck', 'coming', 'back', 'xxxxx']
# preprocessed ['worst']
# preprocessed ['ahem']
# preprocessed ['hate', 'cleaning']
# preprocessed ['feeling', 'big', 'sissys', 'pregnant', 'tomy', 'cool', 'jesus', 'works']
# preprocessed ['ima', 'call', 'night', 'got', 'room', 'bac', 'evrybdy', 'sleep', 'yah', 'got', 'move', 'heavy', 'lil', 'girl', 'wakin', 'gud', 'night', 'twitterlan']
# preprocessed ['headache']
# preprocessed ['hate', 'illness', 'much']
# preprocessed ['oh', 'dear', 'cat', 'brought', 'snake', 'love', 'get', 'presents']
# preprocessed ['oh', 'business']
# preprocessed ['go', 'girl', 'italy', 'rocks']
# preprocessed ['riots', 'fun', 'unfortunatly', 'police', 'far', 'organised', 'began']
# preprocessed ['still', 'sounds', 'like', 'nice', 'day', 'planned', 'enjoy']
# preprocessed ['working', 'new', 'track', 'need', 'dirty', 'sounds', 'xd']
# preprocessed ['first', 'aid', 'shift', 'started', 'excitement', 'kinda', 'died', 'wish', 'could', 'often']
# preprocessed ['sorry', 'hear', 'seejohnswim', 'deleting', 'youtube']
# preprocessed ['listen', 'finally']
# preprocessed ['plight']
# preprocessed ['squarespace', 'sent', 'dm', 'win', 'informed', 'win']
# preprocessed ['remember', 'early', 'homework']
# preprocessed ['mr', 'ek', 'want']
# preprocessed ['lmao', 'mschunli', 'kno', 'done', 'tho', 'lol', 'im', 'drunk', 'nigga']
# preprocessed ['boring', 'day', 'crappy']
# preprocessed ['im', 'sitting', 'nothing', 'tc', 'want', 'come', 'back']
# preprocessed ['collge', 'still', 'bord']
# preprocessed ['may', 'blip', 'one', 'coz', 'love']
# preprocessed ['hi', 'alright', 'thanks', 'ehh', 'bad', 'xx']
# preprocessed ['gorgeous', 'day', 'toronto', 'yet', 'watching', 'simpsons', 'cleaning', 'house', 'ahead', 'family', 'visit', 'tomorrow']
# preprocessed ['trying', 'get', 'rid', 'migraine', 'going', 'work', 'feel', 'like']
# preprocessed ['dear', 'lincolnt', 'stop', 'snoring', 'move', 'middle', 'bed', 'please']
# preprocessed ['agree', 'illegal', 'look', 'good', 'truly', 'unfair']
# preprocessed ['nice', 'bacon']
# preprocessed ['sleeping', 'morning']
# preprocessed ['get', 'ur', 'feelin', 'busted', 'bt', 'time', 'quit', 'practice', 'makes', 'perfect']
# preprocessed ['hate', 'watch', 'weather', 'day', 'nice', 'got', 'car', 'washed', 'amp', 'bout', 'rain']
# preprocessed ['drove', 'home', 'party', 'managed', 'get', 'struck', 'lighting', 'whew', 'scary', 'moments', 'supposed', 'last', 'week']
# preprocessed ['well', 'ss', 'kinda', 'dr', 'rx', 'something', 'bc', 'otc', 'stuff', 'working', 'gone', 'days', 'sleeping']
# preprocessed ['fake']
# preprocessed ['like', 'happy', 'endings']
# preprocessed ['love']
# preprocessed ['hello', 'train', 'heat', 'summer', 'thanks', 'melting', 'frozen', 'yogurt']
# preprocessed ['line', 'quiet', 'came', 'everyone', 'started', 'talking', 'xd', 'even', 'walked', 'past', 'anything']
# preprocessed ['well', 'glad', 'one', 'thought', 'going', 'nuts', 'lol']
# preprocessed ['thankful', 'much', 'tonight', 'love', 'pics', 'camera', 'hearts', 'hahah', 'soooo', 'drunk', 'woooorrrdddd']
# preprocessed ['headacheee', 'read', 'much']
# preprocessed ['hip', 'hop', 'save', 'life', 'wedding', 'dancefloor']
# preprocessed ['think', 'one', 'headphones', 'broken', 'though', 'xxx']
# preprocessed ['homework', 'lie', 'sun', 'met', 'attractive', 'boy', 'named', 'colby', 'work', 'today']
# preprocessed ['bothers']
# preprocessed ['hello', 'lovely', 'people']
# preprocessed ['cant', 'wait', 'meet', 'new', 'cousin', 'leilani', 'shes', 'going', 'look', 'cute', 'new', 'clothes']
# preprocessed ['putting', 'finishing', 'touches', 'album', 'wait', 'lovely', 'people', 'hear']
# preprocessed ['happy', 'see', 'new', 'tweeters', 'found']
# preprocessed ['way', 'rotterdam', 'late', 'appointment']
# preprocessed ['heeyyyy', 'whats', 'girlies']
# preprocessed ['yes']
# preprocessed ['revising', 'gcses']
# preprocessed ['got', 'bug', 'bite', 'butt']
# preprocessed ['ahaha', 'mels', 'followers', 'see', 'youse', 'free', 'time']
# preprocessed ['fave', 'pic', 'joe', 'thud']
# preprocessed ['lol', 'flakey', 'ppl', 'comment', 'heart', 'lol']
# preprocessed ['quot', 'frog', 'coming', 'city', 'stay', 'put', 'angie', 'confirm', 'receipt', 'quot', 'thekidrobb', 'confirm', 'receipt']
# preprocessed ['ah', 'missed', 'sorry', 'ive', 'working', 'change', 'back']
# preprocessed ['hey', 'nelsonaspen', 'love', 'watching', 'sunrise', 'every', 'morning']
# preprocessed ['good', 'grief', 'hopefully', 'painkillers', 'kick', 'soon', 'wishes', 'speedy', 'recovery']
# preprocessed ['pancakes', 'made', 'fail']
# preprocessed ['needs', 'catch', 'homework', 'slacking', 'ugh', 'busy', 'busy', 'night']
# preprocessed ['one', 'single', 'postcard', 'graduated', 'dammit', 'need', 'congratulations']
# preprocessed ['kidding', 'good', 'luck', 'project']
# preprocessed ['send', 'ths', 'mail', 'times', 'every', 'day', 'sure', 'read', 'rlly', 'hope', 'answer']
# preprocessed ['badminton', 'correct', 'spelling', 'always', 'think', 'wrong']
# preprocessed ['broke', 'finger', 'owww']
# preprocessed ['tried', 'true', 'routine', 'go', 'home', 'dinner', 'watch', 'movie', 'sleep']
# preprocessed ['actualy', 'kind', 'special']
# preprocessed ['weird', 'day', 'weird', 'mood', 'treating', 'people', 'lunches', 'likes', 'watch', 'football', 'xx']
# preprocessed ['could', 'make', 'look', 'like', 'stoner', 'punk', 'sheesh', 'let', 'remind', 'real', 'holiday']
# preprocessed ['damn', 'found', 'parked', 'car', 'wrong', 'spot', 'remove', 'day', 'wish', 'luck']
# preprocessed ['yeah', 'lol']
# preprocessed ['weather', 'picture', 'tomorrow', 'toolbar', 'shows', 'thermometer', 'fire', 'good']
# preprocessed ['eeee', 'didnt', 'know', 'piou', 'piou']
# preprocessed ['auditions', 'good', 'iam', 'super', 'nervous', 'one', 'virtues']
# preprocessed ['donna', 'de', 'thank', 'two', 'enjoy', 'day', 'jealous', 'would', 'like', 'near', 'beach']
# preprocessed ['neighbors', 'loud']
# preprocessed ['woo', 'last', 'tweet', 'th', 'wish', 'written', 'something', 'bit', 'insightful', 'next', 'milestone']
# preprocessed ['sorry', 'hear', 'sucks', 'hope', 'ok']
# preprocessed ['casted', 'first', 'votes', 'day', 'goodmorning', 'xx']
# preprocessed ['follow', 'shannylouise', 'shes', 'struggling', 'shes', 'new', 'twitter', 'lol']
# preprocessed ['true', 'quote', 'miss', 'friends', 'moved', 'away', 'life', 'sweeter']
# preprocessed ['am', 'rock', 'super', 'stressing', 'bed', 'real', 'soon', 'think', 'jogging', 'totally', 'feeling', 'like', 'ana']
# preprocessed ['good', 'night', 'nvncyble', 'guess', 'call', 'back', 'pencil', 'masturbating', 'taking', 'shit']
# preprocessed ['hey', 'jared', 'saw', 'videos', 'guys', 'loaded', 'myspace', 'say', 'job', 'well', 'done', 'guys', 'awesome', 'love']
# preprocessed ['giants', 'lost', 'express', 'train', 'back', 'mountain', 'view', 'believe', 'nachos', 'game', 'good', 'good']
# preprocessed ['belive', 'europe', 'good', 'time']
# preprocessed ['ahhh', 'ashley', 'advertising']
# preprocessed ['notice', 'distinct', 'dearth', 'ofcs', 'sv', 'fic', 'though', 'make', 'lana', 'chloe', 'sadly', 'whoever', 'want', 'like', 'tptb']
# preprocessed ['yeah', 'say', 'ad', 'time', 'back', 'hilarious', 'stuff']
# preprocessed ['didnt', 'know', 'either']
# preprocessed ['wish', 'budget', 'bought', 'house', 'good', 'thing', 'work', 'bham', 'else', 'would']
# preprocessed ['dream', 'saw', 'take', 'last', 'night', 'hoping', 'saturday', 'night', 'beats']
# preprocessed ['social', 'last', 'class']
# preprocessed ['followfriday', 'welcome']
# preprocessed ['day', 'nothing']
# preprocessed ['followers', 'keep', 'going', 'hopefully', 'get', 'way', 'one', 'hear', 'lol', 'love', 'life']
# preprocessed ['good', 'afternoon', 'bath', 'breakfast', 'amp', 'lunch', 'resting', 'good', 'luck', 'cloeee', 'exams']
# preprocessed ['talking', 'bf', 'staying', 'midnight', 'hopefully']
# preprocessed ['busy', 'day', 'today', 'amp', 'feel', 'terrrible']
# preprocessed ['played']
# preprocessed ['yay', 'thx', 'kind', 'words', 'makes', 'banana', 'go', 'achy', 'ho', 'ho']
# preprocessed ['would', 'suggest', 'every', 'happy', 'photog', 'hennartonline', 'followfriday', 'request']
# preprocessed ['conny', 'sick']
# preprocessed ['got', 'back', 'fun', 'night', 'old', 'though', 'oh', 'well']
# preprocessed ['dont', 'challenge', 'coronas', 'amp', 'shots', 'grey', 'goose', 'im', 'confident', 'ever', 'sir']
# preprocessed ['time', 'get', 'ready', 'work']
# preprocessed ['quot', 'sigh', 'quot', 'lengthy', 'days', 'week', 'never', 'end']
# preprocessed ['ugh', 'comic', 'con', 'brunch', 'long']
# preprocessed ['im', 'glad', 'get', 'break', 'show', 'im', 'goin', 'swimmin']
# preprocessed ['sorry', 'go']
# preprocessed ['trying', 'avoid', 'lost', 'spoilers', 'still', 'use', 'twitter', 'like', 'trying', 'avoid', 'raindrops', 'hurricane', 'pointless', 'eps', 'behind']
# preprocessed ['new', 'one']
# preprocessed ['sitting', 'munching', 'mozz', 'sticks', 'realizing', 'lucky', 'share', 'life', 'people', 'table']
# preprocessed ['long', 'bridge', 'airport', 'rainy']
# preprocessed ['hate', 'sunburn', 'xxxxxxxx']
# preprocessed ['quot', 'birthday', 'cry', 'want', 'quot']
# preprocessed ['squarespace']
# preprocessed ['anyonghaseyo']
# preprocessed ['dylans', 'mixing', 'ep', 'today']
# preprocessed ['makes', 'sad', 'missed', 'cuz', 'get', 'early', 'next', 'day', 'volunteer', 'cool', 'cuz']
# preprocessed ['feelin', 'kinda', 'nauseous', 'hope', 'wasnt', 'grits']
# preprocessed ['spot', 'bother', 'want', 'finish', 'stupid', 'school', 'works', 'get', 'way', 'aww']
# preprocessed ['last', 'night', 'hollins', 'least', 'vicki', 'sleeping']
# preprocessed ['marianas', 'trench', 'ottawa', 'friend', 'wanted', 'go', 'bad', 'everything', 'already', 'planned']
# preprocessed ['going', 'bed', 'gotta', 'wake', 'early', 'school', 'tommorrow', 'nooooooooooo']
# preprocessed ['think', 'sexy', 'saturday', 'hmm', 'call', 'first']
# preprocessed ['brisbane', 'blast', 'friday', 'night', 'dj', 'rocking', 'final', 'pharmacy', 'family', 'recorvering', 'flu', 'caught', 'club']
# preprocessed ['cannae', 'make', 'time', 'hair', 'expo', 'weekend']
# preprocessed ['oh', 'love', 'know', 'exactly', 'feel', 'apologize', 'hurt', 'anything']
# preprocessed ['god', 'miss', 'come', 'home', 'soon', 'lt']
# preprocessed ['aww', 'okay', 'earlier', 'today', 'mm', 'yeah', 'shudve', 'said', 'yes', 'od', 'im', 'bored']
# preprocessed ['headed', 'first', 'day', 'official', 'work', 'yay', 'pay', 'day', 'today']
# preprocessed ['trying', 'sleep', 'work', 'am']
# preprocessed ['moved', 'twitter', 'think']
# preprocessed ['wanna', 'go', 'raining', 'one', 'comes', 'rains']
# preprocessed ['supernatural', 'theme', 'song']
# preprocessed ['much']
# preprocessed ['unhappy', 'lost', 'somebody', 'happy', 'grandgrandma', 'crying']
# preprocessed ['well', 'swgeekgirls', 'got', 'stick', 'together', 'lomara', 'many', 'surfaced', 'good', 'friends']
# preprocessed ['way', 'softball', 'game', 'got', 'stop', 'dunhams', 'get', 'different', 'softball', 'pants', 'lol', 'small']
# preprocessed ['missed', 'people']
# preprocessed ['ok', 'ur', 'missin', 'ur', 'bunny', 'understandable']
# preprocessed ['curiouslt', 'working', 'sunday', 'sucks']
# preprocessed ['welcome']
# preprocessed ['aqualung', 'barca', 'kor', 'suu', 'kyi', 'oh', 'yeah', 'laodicean', 'anyway', 'bianca', 'uber', 'indie', 'brighter', 'sunshine', 'hehe']
# preprocessed ['yeah', 'brenda', 'always', 'fave']
# preprocessed ['picked', 'stuff', 'missed', 'nd', 'time', 'think', 'missed', 'jokes']
# preprocessed ['rather', 'hungry']
# preprocessed ['wondering', 'foundation', 'get', 'deliverd', 'boots']
# preprocessed ['actually', 'meant', 'say', 'tweet', 'hamlet', 'penelope', 'wilton', 'played', 'harriet', 'jones', 'former', 'prime', 'minister']
# preprocessed ['really', 'go', 'sleep', 'work', 'afternoon', 'goodnight']
# preprocessed ['hate', 'break', 'ya', 'swifty', 'portman', 'beat', 'actually', 'funny']
# preprocessed ['actually', 'fail', 'intent', 'along', 'sell', 'workers', 'create', 'consumer', 'based', 'economies', 'politricks']
# preprocessed ['hail', 'scaring', 'miss', 'michael', 'ryan']
# preprocessed ['totally', 'agree']
# preprocessed ['fucking', 'twitter', 'wrong', 'one', 'updates', 'sending', 'phone']
# preprocessed ['hoping', 'mine', 'time', 'want', 'anyone', 'deleted', 'everyone', 'looked', 'pretty']
# preprocessed ['good', 'paddy', 'hiy', 'days', 'im', 'gonna', 'goin', 'wild', 'cant', 'wait']
# preprocessed ['babysitting', 'today', 'hanging', 'best', 'frenn']
# preprocessed ['think', 'mad', 'ignoring', 'day', 'know', 'though']
# preprocessed ['rest', 'need', 'wait', 'couple', 'days']
# preprocessed ['nan']
# preprocessed ['happy', 'idol', 'results', 'going', 'kick', 'ass', 'finale']
# preprocessed ['yeah', 'wings', 'loooooove', 'elliot']
# preprocessed ['crap', 'slumdog', 'twilight', 'two', 'song', 'much', 'better']
# preprocessed ['lost', 'us', 'ending', 'mean', 'eat', 'greypoupon', 'anything', 'prefer', 'bleaker', 'original']
# preprocessed ['feeling', 'good', 'today', 'fb']
# preprocessed ['wait', 'till', 'concert', 'tomoz', 'exams', 'concert', 'celebrate']
# preprocessed ['thanks', 'retweet']
# preprocessed ['oh', 'bob', 'didnt', 'see']
# preprocessed ['well', 'bought', 'complete', 'set', 'dead', 'like', 'watch', 'whole', 'thing']
# preprocessed ['btw', 'still', 'lt', 'though']
# preprocessed ['fear', 'bluffing', 'go', 'far']
# preprocessed ['enjoy', 'choral', 'project', 'last', 'night', 'friday', 'fantastic', 'show', 'actually', 'good', 'watch', 'photos']
# preprocessed ['seem', 'headed', 'going', 'cry', 'great', 'big', 'pillow', 'right']
# preprocessed ['totally', 'would', 'supposed', 'working', 'right', 'maybe', 'anyways']
# preprocessed ['seriously', 'confused']
# preprocessed ['leaving', 'nooo', 'need', 'long', 'gone', 'forever', 'forever', 'take', 'forever']
# preprocessed ['hopefully', 'yes', 'hope', 'weather', 'like', 'today']
# preprocessed ['made', 'pages', 'tumblr', 'feel', 'accomplished', 'goodnight']
# preprocessed ['yay', 'drunk', 'meg', 'much', 'fun', 'tipple', 'tonight']
# preprocessed ['oh', 'good', 'apparently', 'go', 'town', 'much', 'lazy', 'day', 'oh', 'well', 'always', 'tomorrow', 'months', 'ha']
# preprocessed ['want', 'hear', 'phone', 'call', 'jordan', 'tomorrow']
# preprocessed ['dadnapped', 'shown', 'singapore', 'forgot']
# preprocessed ['video', 'take', 'look', 'excuse', 'voice', 'though', 'feeling', 'bad', 'today', 'oh', 'well', 'vids']
# preprocessed ['uft', 'im', 'tutoring', 'lil', 'sis', 'shes', 'cute', 'even', 'though', 'shes', 'eighth', 'grader']
# preprocessed ['flylady', 'good', 'morning', 'dh', 'fix', 'computer', 'acting', 'strange', 'yesterday', 'amp', 'get', 'anything']
# preprocessed ['union', 'fine']
# preprocessed ['cannot', 'believe', 'am', 'sunday', 'stupid', 'people', 'need', 'phone', 'numbers', 'called', 'phone', 'book', 'use']
# preprocessed ['show', 'egon', 'agora', 'tchau']
# preprocessed ['working', 'gotta', 'love', 'day', 'weekend']
# preprocessed ['sorry', 'hun', 'tried', 'guess', 'ill', 'make']
# preprocessed ['another', 'one', 'bites', 'dust']
# preprocessed ['go', 'sleep', 'mr', 'jones', 'cuddle', 'brucie', 'xx']
# preprocessed ['wooo', 'final', 'exam', 'tomorro', 'done', 'shame', 'got', 'say', 'bye', 'though']
# preprocessed ['hockeys', 'pretty', 'funny', 'joke', 'hockey', 'forgot', 'michael', 'tozer', 'going', 'aar']
# preprocessed ['agh', 'wanted', 'try', 'new', 'iphone', 'op', 'system', 'left', 'phone', 'home']
# preprocessed ['ok', 'bad', 'even', 'trip', 'subject', 'ese', 'lmao']
# preprocessed ['hey', 'remember', 'talked', 'jaque', 'phone', 'friend', 'mary', 'follow']
# preprocessed ['watching', 'jay', 'leno', 'last', 'show']
# preprocessed ['mispelled', 'twitter', 'name']
# preprocessed ['twittering', 'ever', 'weeks', 'cut', 'around', 'hehe']
# preprocessed ['lol', 'okay', 'uhh', 'still', 'love', 'best', 'know', 'youre', 'always']
# preprocessed ['da', 'dont', 'wanna', 'go', 'work']
# preprocessed ['somehow', 'going', 'glastonbury', 'thanks', 'worm', 'someone', 'upstairs', 'like']
# preprocessed ['okay', 'cool', 'like', 'camool', 'zoo']
# preprocessed ['sitting', 'computer', 'looking', 'bbpmeet', 'listening', 'yahoo', 'knowing', 'sleep', 'im', 'definetly', 'going', 'work', 'tomorrow']
# preprocessed ['upset', 'upset']
# preprocessed ['dont', 'knock', 'till', 'tried', 'manly', 'yummy', 'drink']
# preprocessed ['try', 'home', 'search', 'video', 'monetization', 'video', 'advertising', 'twitter', 'nothing', 'comes', 'crowded', 'space', 'huh']
# preprocessed ['tried', 'make', 'impulse', 'book', 'buy', 'got', 'stuck', 'trying', 'decide', 'one', 'choose', 'tbr', 'list']
# preprocessed ['haha', 'mario', 'kart', 'gets', 'intense', 'forget', 'blink']
# preprocessed ['get', 'iphone', 'better', 'selection', 'games', 'haha']
# preprocessed ['fuck', 'mixtape']
# preprocessed ['dont', 'think', 'agressive', 'male', 'dogs']
# preprocessed ['lol', 'supporting', 'tht', 'black', 'list', 'might', 'hav', 'turn', 'white', 'lol', 'got', 'blks', 'following', 'babe']
# preprocessed ['hey', 'lj']
# preprocessed ['back', 'pain', 'good']
# preprocessed ['back', 'work', 'morrow', 'sucks']
# preprocessed ['thanks', 'glasgow', 'weather']
# preprocessed ['probably', 'smartest', 'idea', 'chug', 'large', 'cuban', 'coffee', 'espresso', 'shots', 'night', 'dumb', 'dumb', 'dumb', 'feel', 'hott']
# preprocessed ['effectively', 'sacked', 'julia', 'favourite', 'show', 'sure', 'get']
# preprocessed ['peaceful', 'miles', 'somehow', 'got', 'whole', 'house', 'wow', 'dunno', 'quiet']
# preprocessed ['hiding']
# preprocessed ['going', 'tim', 'amp', 'jessicas', 'game', 'night', 'poor', 'rooby', 'still', 'animal', 'hosp', 'hopefully', 'bring', 'home', 'tomorrow']
# preprocessed ['sweden', 'everybody', 'loves']
# preprocessed ['soooo', 'tired', 'time', 'bed', 'back', 'pillow', 'face']
# preprocessed ['like', 'big', 'sissie']
# preprocessed ['sick', 'tired', 'creeping', 'computer', 'adrienne', 'cuddling', 'james', 'makes', 'feel', 'better', 'tho', 'home', 'time', 'bed']
# preprocessed ['final', 'exams', 'start', 'wednesday', 'thank', 'friends', 'told', 'start', 'next', 'week', 'assholes']
# preprocessed ['go', 'bed', 'till', 'am', 'heck']
# preprocessed ['pulled', 'nighter', 'actually', 'slept']
# preprocessed ['sampe', 'rumah', 'ai', 'long', 'time', 'see', 'curhat', 'session', 'bigeyes', 'udah', 'lama', 'ga', 'nginep', 'depok']
# preprocessed ['missed']
# preprocessed ['still', 'twittertakeover', 'hope', 'fully', 'keep', 'cloud', 'list', 'special', 'people']
# preprocessed ['really', 'cool', 'kate', 'really', 'looked', 'like', 'real', 'one', 'lt', 'uninstall', 'though', 'made', 'computer', 'reallyyy', 'slow']
# preprocessed ['damn', 'missin', 'babies']
# preprocessed ['really', 'proud', 'polish', 'talk', 'representation', 'euruko']
# preprocessed ['washington', 'state', 'making', 'good', 'time', 'exhausted']
# preprocessed ['hello', 'everyone', 'good', 'morning', 'mascara', 'difficult', 'get']
# preprocessed ['trying', 'get', 'sick', 'must', 'say', 'hair', 'looks', 'pretty', 'fly']
# preprocessed ['cheers', 'writing', 'wonderfully', 'straightforward', 'piece', 'always', 'understood', 'able', 'express']
# preprocessed ['yes', 'love', 'agree', 'boston', 'today', 'raining', 'nj']
# preprocessed ['soooooooo', 'cold', 'england', 'day', 'thought', 'supposed', 'summer', 'like', 'south', 'africa', 'winter']
# preprocessed ['way', 'time', 'eat', 'breakmas']
# preprocessed ['lol', 'thank']
# preprocessed ['forgot', 'uncubicled', 'got', 'work']
# preprocessed ['difficult', 'interview']
# preprocessed ['omg', 'never', 'done', 'reading', 'could', 'long', 'semester']
# preprocessed ['sry', 'tweeting', 'much', 'today', 'lol', 'awhile', 'might', 'tomorrow', 'today', 'lol', 'idk', 'leaving', 'thursday', 'funeral', 'reunion']
# preprocessed ['school', 'rehersals', 'gonna', 'free', 'day', 'love', 'rehersals', 'lt', 'lt', 'lt']
# preprocessed ['corinthians', 'makes', 'feel', 'warm', 'fuzzy']
# preprocessed ['aww', 'niece', 'pointed', 'huge', 'thumbs']
# preprocessed ['thinking', 'cycling', 'thing', 'hell', 'lot', 'fun']
# preprocessed ['prolly', 'going', 'bed', 'soon', 'imm', 'super', 'hyper', 'textt']
# preprocessed ['quot', 'laney', 'someone', 'gonna', 'leak', 'sex', 'tape', 'quot', 'damnn', 'thought', 'laney', 'first']
# preprocessed ['ima', 'miss', 'katarina', 'gets', 'see', 'every', 'years', 'lt', 'quot', 'came', 'back', 'give', 'another', 'hug', 'cause', 'love', 'much', 'miss', 'quot']
# preprocessed ['thanks', 'yes', 'pretty', 'chipper', 'moment', 'enjoying', 'good', 'weather', 'wisiting', 'sw']
# preprocessed ['day', 'make', 'happy']
# preprocessed ['lol', 'thank']
# preprocessed ['go', 'back', 'work', 'tomorrow']
# preprocessed ['picked', 'bike', 'morning', 'got', 'coolest', 'mechanic']
# preprocessed ['ask', 'forgiveness', 'still', 'sing', 'tho']
# preprocessed ['trying', 'watch', 'movie', 'people', 'house', 'uhhhhh']
# preprocessed ['happy', 'mother', 'day', 'moms']
# preprocessed ['know', 'right', 'ok', 'hope', 'tho', 'lol']
# preprocessed ['sad', 'hate']
# preprocessed ['fun']
# preprocessed ['rubicon', 'river', 'cross', 'act', 'war', 'horse', 'part', 'ok', 'smart']
# preprocessed ['two', 'people', 'morning', 'already', 'come', 'hummingbird', 'cake', 'coffee', 'dessert', 'breakfast', 'food']
# preprocessed ['one', 'think', 'tell', 'kyle', 'xy', 'bbc', 'missed', 'whole', 'series']
# preprocessed ['stuffwotimadeup', 'going', 'be', 'fifth', 'girls', 'aloud', 'nicola', 'lock', 'dressing', 'room', 'missed', 'finals', 'bitch']
# preprocessed ['last', 'day', 'greece', 'dibz', 'im', 'gonna', 'miss', 'kids', 'much', 'im', 'gonna', 'cry']
# preprocessed ['nah', 'need', 'another', 'beer']
# preprocessed ['know', 'biggest', 'smile', 'face']
# preprocessed ['packed', 'ready', 'weekend', 'although', 'finish', 'work', 'till', 'nearly', 'pm', 'tomorrow']
# preprocessed ['okay', 'never', 'mind', 'bummertime']
# preprocessed ['remember', 'stronger', 'feel', 'smarter', 'think', 'amazing', 'people', 'ever', 'hope', 'ti']
# preprocessed ['pain', 'much']
# preprocessed ['bigger', 'house']
# preprocessed ['back', 'work']
# preprocessed ['woke', 'long', 'night', 'tired']
# preprocessed ['grrrr', 'tummy', 'hurts']
# preprocessed ['dont', 'even', 'know', 'anymore', 'use', 'best', 'bud', 'got', 'amp', 'look', 'urself']
# preprocessed ['detroit', 'missed']
# preprocessed ['finally', 'effing', 'internet', 'effin', 'need', 'update', 'wifi', 'sg', 'malls', 'idk', 'miss', 'dada', 'craigie']
# preprocessed ['get', 'followers', 'day', 'using', 'www', 'tweeteradder', 'com', 'add', 'everyone', 'train', 'pay', 'vip']
# preprocessed ['eadave', 'wish', 'could', 'come', 'show', 'coming', 'wisconsin']
# preprocessed ['helping', 'friends', 'pack', 'tiring', 'im', 'well', 'rested']
# preprocessed ['watching', 'anc', 'leadership', 'forum']
# preprocessed ['sooooo', 'much']
# preprocessed ['oh', 'god', 'god', 'much', 'work', 'done', 'weekend', 'barely', 'started', 'revision', 'maths', 'exam', 'tuesday', 'history', 'wednesday']
# preprocessed ['called', 'answer', 'call', 'back']
# preprocessed ['many', 'ppl', 'dis', 'stratford', 'day', 'well', 'got', 'new', 'friendddd']
# preprocessed ['yay', 'apartment', 'knoxville', 'move', 'july', 'st']
# preprocessed ['nan']
# preprocessed ['mum', 'knows', 'different', 'sites', 'get', 'tickets', 'hoping', 'get', 'im', 'gonna', 'scream']
# preprocessed ['im', 'sorry', 'woke', 'morning', 'felt', 'like', 'shit', 'went', 'back', 'bed', 'got', 'point', 'coming', 'school']
# preprocessed ['quot', 'boy', 'trying', 'change', 'life', 'better', 'quot', 'bring']
# preprocessed ['biggest', 'thought', 'right']
# preprocessed ['damn', 'got', 'first', 'try']
# preprocessed ['head', 'aches']
# preprocessed ['never', 'celebrate', 'fathers', 'day']
# preprocessed ['macbook', 'pro', 'longer', 'snappy', 'nothing', 'opens', 'instantly', 'anymore', 'bouncing', 'dock', 'icons', 'place']
# preprocessed ['baked', 'cake', 'taste', 'good']
# preprocessed ['lol', 'true', 'page']
# preprocessed ['jay', 'jon', 'kate', 'spliting', 'make', 'stop']
# preprocessed ['erin', 'leaving', 'today', 'lansing', 'gonna', 'get', 'lonley']
# preprocessed ['bout', 'soundcheck', 'gona', 'go', 'live', 'internet', 'messed', 'unfortunately', 'performin', 'white', 'affair', 'comedy', 'partay', 'yay']
# preprocessed ['pretty', 'alright', 'weekend']
# preprocessed ['pictures', 'food']
# preprocessed ['never', 'never', 'never', 'give', 'thanks', 'ff']
# preprocessed ['got', 'classes', 'next', 'year', 'bit', 'ah', 'bit', 'int', 'higher', 'losing', 'science', 'getting', 'new', 'sci', 'amp', 'phys']
# preprocessed ['getting', 'ready', 'work']
# preprocessed ['dont', 'know', 'work', 'upper', 'lower', 'quatile', 'range', 'im', 'gonna', 'fail', 'sure']
# preprocessed ['try', 'reasons', 'suspense', 'drama', 'amp', 'romance', 'rose', 'melinda', 'cried', 'amp', 'seeing']
# preprocessed ['want', 'say', 'goodbye']
# preprocessed ['red', 'wine', 'given', 'ouchy', 'head']
# preprocessed ['uh', 'oh', 'ass', 'gonna', 'need', 'kick']
# preprocessed ['thanks', 'soren']
# preprocessed ['bebetooo', 'miss', 'youuu']
# preprocessed ['good', 'morning', 'got', 'midterm', 'quiz', 'today', 'class', 'excited', 'want', 'done', 'already']
# preprocessed ['case', 'mondays']
# preprocessed ['international', 'day', 'hudson']
# preprocessed ['band', 'recorded', 'new', 'song', 'follow', 'us', 'dontblamethem', 'listen', 'us', 'nite']
# preprocessed ['hahau', 'send', 'swap']
# preprocessed ['gooddog', 'ghosts', 'hate']
# preprocessed ['im', 'trying', 'increase', 'fan', 'base']
# preprocessed ['figures', 'finish', 'single', 'speed', 'rains', 'week']
# preprocessed ['think', 'saying', 'example', 'one', 'zc', 'mean', 'thing', 'set', 'valid', 'zcs']
# preprocessed ['arabik', 'also', 'know', 'come', 'question']
# preprocessed ['scattergories', 'great', 'fun']
# preprocessed ['chow', 'dog', 'yrs', 'baby', 'passed', 'away', 'hours', 'ago', 'sad', 'took', 'one', 'last', 'walk', 'around', 'neighborhood', 'miss', 'lot']
# preprocessed ['still', 'grandma', 'house', 'family', 'meeting']
# preprocessed ['great', 'time', 'tonight', 'old', 'friends', 'felt', 'good', 'tell', 'stories', 'laugh', 'life', 'old', 'memories']
# preprocessed ['sad', 'cat', 'hurt']
# preprocessed ['hahaha', 'sobra', 'although', 'one', 'interviewers', 'cute', 'hey', 'course', 'parang', 'ang', 'hirap', 'ng', 'mga', 'inaaral', 'mo']
# preprocessed ['fyi', 'area', 'easton', 'rep', 'rich', 'igo', 'best']
# preprocessed ['wanna', 'get', 'lip', 'ring', 'every']
# preprocessed ['leaving', 'go', 'lilmarshmellows', 'house']
# preprocessed ['minute', 'run', 'first', 'one', 'weeks', 'amp', 'coughing', 'countdown', 'bridge', 'brisbane', 'begins']
# preprocessed ['library', 'day', 'today', 'go', 'library', 'get', 'worthwhile', 'books', 'audiobooks', 'schlep', 'booty', 'back', 'home']
# preprocessed ['stil', 'feeling', 'sick', 'officially', 'fan', 'emergency', 'rooms']
# preprocessed ['worry', 'got', 'brain', 'woke', 'ill', 'email', 'shortly']
# preprocessed ['laying', 'grandparents', 'pool', 'work']
# preprocessed ['academics', 'kill', 'waka']
# preprocessed ['welcome', 'glad', 'enjoyed']
# preprocessed ['days', 'movies', 'diet', 'fail']
# preprocessed ['miss', 'come', 'back']
# preprocessed ['album', 'wickedd']
# preprocessed ['twitter', 'great']
# preprocessed ['finished', 'giving', 'boyfriend', 'haircut']
# preprocessed ['yay', 'hour', 'home']
# preprocessed ['always', 'rice', 'belly', 'since', 'age', 'probably', 'never', 'leave', 'matter', 'much', 'run', 'welcome']
# preprocessed ['still', 'caught', 'days', 'sleep', 'lost', 'europe', 'probably', 'never', 'soooo', 'glad', 'back']
# preprocessed ['form', 'working', 'way']
# preprocessed ['disgusting', 'outside', 'today', 'want', 'leave', 'house']
# ...
# preprocessed ['yes', 'yes', 'yes']
# preprocessed ['laying', 'bed', 'thinking', 'lost', 'close']
# preprocessed ['shoppingg']
# preprocessed ['im', 'still', 'bored', 'tired']
# preprocessed ['picture', 'sweet', 'madison', 'blessing']
# preprocessed ['hate', 'waiting', 'doctors', 'offices']
# preprocessed ['ahh', 'music', 'video', 'premiere', 'davidarchie', 'touch', 'hand', 'loveit', 'starting', 'vote', 'hoorah', 'goodeve']
# preprocessed ['haha', 'oldest', 'one', 'anything', 'wrong', 'fb', 'pf', 'pic', 'small']
# preprocessed ['im', 'done', 'think', 'wrap', 'deonte', 'loggin']
# preprocessed ['reading', 'cook', 'illus', 'salt', 'content', 'diff', 'every', 'brand', 'know', 'help']
# preprocessed ['rehearsals', 'today']
# preprocessed ['really', 'upset', 'im', 'prolly', 'going', 'get', 'house', 'wanted']
# preprocessed ['aww', 'sweet', 'girlie', 'thanx', 'today', 'miss', 'flyy']
# preprocessed ['yo', 'whats', 'im', 'bout', 'get', 'homie', 'amp', 'go', 'day', 'sorry', 'missed', 'ur', 'party', 'wuz', 'baby', 'sitting', 'wuz']
# preprocessed ['work', 'hours', 'hours', 'sleep', 'let', 'go']
# preprocessed ['sorry', 'hear', 'tomorrow', 'better']
# preprocessed ['today', 'started', 'well']
# preprocessed ['awww', 'sure', 'yellow', 'queen', 'kids', 'getting', 'juice']
# preprocessed ['got', 'new', 'glasses', 'wanted', 'blue', 'ones', 'though']
# preprocessed ['days', 'school', 'today', 'drama', 'english', 'finals', 'didnt', 'read', 'crucible', 'sparknote', 'haha', 'wish', 'luck']
# preprocessed ['help', 'worry', 'whats', 'happened', 'need', 'feel', 'lost', 'iloveyouu', 'thanks', 'tweeting', 'lt']
# preprocessed ['read', 'jealous', 'starving']
# preprocessed ['mad', 'jon', 'amp', 'kate']
# preprocessed ['thanks', 'recommendation', 'hope', 'great', 'saturday']
# preprocessed ['thankyou']
# preprocessed ['stalk', 'follow', 'twitter']
# preprocessed ['love', 'song', 'miss', 'band', 'bbmak', 'quot', 'unpredictable', 'quot', 'musicmonday']
# preprocessed ['mom', 'likes', 'read', 'janet', 'evanovich', 'james', 'patterson', 'harlan', 'coben']
# preprocessed ['throat', 'hurts', 'gosh']
# preprocessed ['well', 'hehe']
# preprocessed ['need', 'knock', 'feeling', 'well']
# preprocessed ['sorry', 'sayang', 'pls', 'dun', 'upset', 'wif']
# preprocessed ['make', 'new', 'youtube', 'videos', 'love']
# preprocessed ['speaking', 'neilhimself', 'pulling', 'every', 'string', 'disposal', 'try', 'get', 'ticket', 'see', 'luminato', 'jun', 'luck']
# preprocessed ['bahaha', 'twitterrific', 'fun', 'convenient', 'minutes', 'go', 'sighs']
# preprocessed ['oops', 'forgot', 'cars', 'repressed', 'yes', 'much', 'much', 'better', 'cars']
# preprocessed ['thought', 'gonna', 'year', 'year', 'bad', 'luck', 'happen']
# preprocessed ['yay', 'sweet', 'bound', 'happen', 'numbers', 'topping', 'million', 'xboxe']
# preprocessed ['joel', 'middle', 'pointing', 'camera']
# preprocessed ['thank', 'people', 'say', 'though', 'listen', 'public', 'yeah', 'best', 'friends', 'gay']
# preprocessed ['share', 'ree', 'going', 'post', 'blog', 'soon', 'lazy', 'well', 'update', 'plurk']
# preprocessed ['sitting', 'parents', 'office', 'day', 'left', 'school']
# preprocessed ['tired', 'need', 'caffeine', 'please', 'many', 'things', 'also', 'get', 'mbp', 'next', 'week']
# preprocessed ['naturally']
# preprocessed ['nice', 'hosting', 'sounds', 'like']
# preprocessed ['wait', 'closed', 'beta', 'gone']
# preprocessed ['leaving']
# preprocessed ['hours', 'finding', 'much']
# preprocessed ['sounds', 'good', 'happiness', 'underrated']
# preprocessed ['mondays', 'boring', 'people']
# preprocessed ['trying', 'desperately', 'find', 'swim', 'team', 'twitter']
# preprocessed ['haha', 'love']
# preprocessed ['arrgghhh', 'exams', 'go', 'lol']
# preprocessed ['hi', 'cant', 'upload', 'pics', 'reason', 'nice', 'pics', 'saw', 'ad', 'think', 'interesti']
# preprocessed ['chill', 'babes', 'qet', 'thong', 'butt', 'already']
# preprocessed ['derby', 'fabulous', 'rain', 'held', 'day', 'pics', 'come']
# preprocessed ['reason', 'hand', 'hurts', 'worse', 'ever', 'today']
# preprocessed ['cats', 'gone', 'pets', 'till', 'house', 'miss', 'never', 'thought', 'would', 'much', 'bye', 'bye', 'kitties']
# preprocessed ['much', 'work', 'instant', 'gratification', 'muscle', 'milk', 'delish', 'though']
# preprocessed ['hey', 'demi', 'really', 'love', 'songs', 'amazing', 'voice', 'keep', 'rockin']
# preprocessed ['nahh', 'third']
# preprocessed ['wish', 'kids', 'excuse', 'go', 'aquarium']
# preprocessed ['thanks', 'recommending']
# preprocessed ['posting', 'notes', 'discussions', 'psychology', 'class', 'two', 'years', 'ago']
# preprocessed ['get', 'see']
# preprocessed ['got', 'reply', 'fpom', 'mutya', 'yay']
# preprocessed ['number', 'shabby', 'looken']
# preprocessed ['gonna', 'quit', 'quit', 'like', 'winner', 'love', 'josh', 'pyke', 'brings', 'smile', 'brace', 'face']
# preprocessed ['drove', 'pike', 'county', 'today', 'including', 'going', 'virginia', 'wish', 'gas', 'still']
# preprocessed ['ow', 'little', 'body', 'sore']
# preprocessed ['cheatlake']
# preprocessed ['happy', 'mothers', 'day', 'im', 'spend', 'day', 'family']
# preprocessed ['first', 'time', 'either', 'couple', 'days', 'nothing', 'specific', 'maybe', 'packing', 'tidying']
# preprocessed ['mm', 'salad', 'tea', 'yummy', 'time', 'properly', 'revise', 'suppose']
# preprocessed ['kjifrkefjsgpoti', 'rjdi', 'want', 'quot', 'troy', 'quot', 'climb', 'bedroom', 'sing']
# preprocessed ['got', 'back', 'movies', 'blast', 'lil', 'brothers', 'today', 'nuttts', 'missing', 'like', 'crazyyy', 'hit', 'cell']
# preprocessed ['confession', 'seen', 'high', 'school', 'musical', 'amp', 'adolescence', 'nothing', 'like', 'movie']
# preprocessed ['understand', 'people', 'bring', 'convicted', 'offender', 'home', 'kids', 'first', 'place', 'real', 'shame']
# preprocessed ['surfing', 'net', 'geez', 'chucks', 'anoyying']
# preprocessed ['hahaha', 'made', 'get', 'twitter', 'yay']
# preprocessed ['iso', 'arrggh']
# preprocessed ['owww', 'managed', 'really', 'stub', 'toe', 'blue', 'swollen', 'running', 'may', 'deferred', 'days', 'dammit']
# preprocessed ['ohhhhh', 'haha', 'thought', 'done', 'haha', 'didnt', 'find', 'anything']
# preprocessed ['maybe', 'pay', 'somebody', 'take', 'care', 'need', 'personal', 'nurse']
# preprocessed ['isplayer', 'died', 'sorry']
# preprocessed ['long', 'time', 'nobody', 'really', 'cares', 'followers', 'really', 'anyway', 'haha', 'life', 'sucks', 'right', 'though']
# preprocessed ['surely', 'got', 'weekend', 'think', 'getting', 'stage', 'needing', 'holiday', 'weekends', 'short', 'weeks', 'long']
# preprocessed ['mmm', 'good', 'morning']
# preprocessed ['miss', 'boyfriend']
# preprocessed ['want', 'glass', 'wine', 'much', 'sun', 'headache', 'think']
# preprocessed ['aah', 'want', 'hulu', 'available', 'belgium']
# preprocessed ['talk', 'mean', 'wish', 'ripe']
# preprocessed ['really', 'thank', 'know', 'still', 'new', 'mac']
# preprocessed ['jdryden', 'gives', 'push', 'calendars', 'contacts', 'almost', 'like', 'com', 'else', 'could', 'want', 'oh', 'yeah', 'push', 'email', 'min', 'fetch', 'cool']
# preprocessed ['hey', 'looking', 'around', 'internet']
# preprocessed ['tuesday', 'fully', 'booked', 'hour', 'god', 'sound', 'like', 'high', 'class', 'prostitute', 'got', 'family', 'functions', 'stuff', 'dear']
# preprocessed ['minute', 'till', 'everything', 'gets', 'deleted', 'sorry', 'guys']
# preprocessed ['keep', 'mind', 'gets', 'tonked', 'overs']
# preprocessed ['watching', 'supernatural', 'gossip', 'girl', 'stopped', 'middle', 'wasnt', 'even', 'half']
# preprocessed ['one', 'quick', 'chai', 'bed', 'early', 'start', 'am']
# preprocessed ['really', 'text']
# preprocessed ['new', 'moon', 'trailer', 'makes', 'laugh', 'higher', 'hopes', 'different', 'director', 'much', 'anymore']
# preprocessed ['congrats', 'jodi', 'carlson']
# preprocessed ['saw', 'irvine', 'rally', 'big', 'turn', 'lots', 'honking', 'support', 'unable', 'take', 'pics', 'tho', 'iranelection']
# preprocessed ['goingto', 'beds', 'killer', 'headache']
# preprocessed ['voted', 'every', 'category', 'nominated', 'im', 'prayin', 'ya']
# preprocessed ['boom', 'boom', 'pow', 'song', 'itunes', 'question', 'itunes', 'song', 'black', 'eyed', 'pees']
# preprocessed ['nice', 'idea', 'cakes', 'get', 'squished', 'post', 'although', 'probably', 'look', 'better', 'way', 'ha']
# preprocessed ['probably', 'storage', 'somewhere', 'cali']
# preprocessed ['haha', 'come', 'join', 'trying', 'get', 'day', 'work']
# preprocessed ['ask', 'wimax']
# preprocessed ['good', 'advice', 'unfollowing', 'found', 'great', 'tweeps', 'follow']
# preprocessed ['didnt', 'get', 'text', 'think', 'prob', 'sent', 'wrong', 'always', 'phone', 'wit', 'yeah', 'man', 'work', 'today']
# preprocessed ['thinking', 'hiding', 'footy', 'btw']
# preprocessed ['come', 'phone', 'let', 'upgrade', 'software', 'says', 'latest']
# preprocessed ['need', 'post', 'video', 'stuck']
# preprocessed ['misses', 'using', 'tweetdeck']
# preprocessed ['making', 'drive', 'wife', 'cackling', 'mates', 'pub', 'tonight']
# preprocessed ['new', 'zealand', 'mistaken', 'bit', 'far']
# preprocessed ['really', 'headaches', 'lft', 'jaw', 'killing', 'cuz', 'cut', 'gums', 'get', 'tooth', 'pieces']
# preprocessed ['back', 'hospital']
# preprocessed ['one', 'fave', 'places', 'wingstop']
# preprocessed ['luv', 'hillbilly', 'work', 'accent', 'live', 'texas', 'grew', 'chicago', 'ca', 'yrs', 'soften', 'chicago', 'accent']
# preprocessed ['great', 'thanks', 'go', 'look', 'site']
# preprocessed ['dont', 'brake', 'shot', 'clocks', 'anymore', 'lol', 'good', 'luck', 'today', 'dwight', 'amazing']
# preprocessed ['austria', 'chance', 'take', 'part', 'wm', 'anymore']
# preprocessed ['lol', 'let', 'good', 'reason', 'good', 'un']
# preprocessed ['im', 'listening', 'wendy', 'williams', 'rite', 'bored', 'outta', 'mind']
# preprocessed ['hey', 'yea', 'kno', 'dammit', 'xd', 'marsiscoming', 'marsiscoming', 'marsiscoming', 'marsiscoming']
# preprocessed ['packing', 'almost', 'done']
# preprocessed ['nataliewitcher', 'miss', 'ok', 'girls', 'happy', 'mother', 'day']
# preprocessed ['laughs', 'good', 'bday']
# preprocessed ['nope', 'still', 'got', 'cold', 'keep', 'losing', 'voice', 'amp', 'really', 'sore', 'throat', 'back', 'nose', 'bout']
# preprocessed ['dm', 'since', 'following']
# preprocessed ['think', 'bday', 'going', 'magic', 'castle', 'got', 'invite']
# preprocessed ['yeah', 'esme', 'kate', 'carmen', 'would', 'definetly', 'help', 'way', 'could']
# preprocessed ['know', 'want', 'video', 'games', 'ska', 'clothing', 'maybe', 'watch', 'predicts', 'weather']
# preprocessed ['awwww', 'sorry', 'loss', 'kitty', 'hit', 'car', 'last', 'year']
# preprocessed ['got', 'one', 'tests', 'wrists']
# preprocessed ['love', 'fridays', 'short', 'work', 'day', 'amp', 'early', 'start', 'weekend', 'altho', 'allergies', 'putting', 'damper', 'things', 'today']
# preprocessed ['followers', 'subscribers', 'week', 'unbelieveable', 'us', 'thankyou', 'everybody', 'helping', 'us', 'making', 'us', 'happy']
# preprocessed ['listening', 'yiruma', 'little', 'brother']
# preprocessed ['xanax', 'miss', 'cuddling', 'ass']
# preprocessed ['getting', 'little', 'mowing', 'grass', 'evening', 'fun']
# preprocessed ['music', 'listen', 'ipod']
# preprocessed ['appreciating', 'little', 'things', 'life', 'good', 'morning', 'world']
# preprocessed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-6192eb36a4e3> in <module>
#      19         #print("Total words:", total_words)
#      20 sentences = TweetCorpus()
# ---> 21 model = gensim.models.Word2Vec(sentences=sentences, window=10, iter=1, size=300, min_count=1, sg=0)
#
# ~/anaconda3/envs/snlp_env/lib/python3.6/site-packages/gensim/models/word2vec.py in __init__(self, sentences, corpus_file, size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, ns_exponent, cbow_mean, hashfxn, iter, null_word, trim_rule, sorted_vocab, batch_words, compute_loss, callbacks, max_final_vocab)
#     781             callbacks=callbacks, batch_words=batch_words, trim_rule=trim_rule, sg=sg, alpha=alpha, window=window,
#     782             seed=seed, hs=hs, negative=negative, cbow_mean=cbow_mean, min_alpha=min_alpha, compute_loss=compute_loss,
# --> 783             fast_version=FAST_VERSION)
#     784
#     785     def _do_train_epoch(self, corpus_file, thread_id, offset, cython_vocab, thread_private_mem, cur_epoch,
#
# ~/anaconda3/envs/snlp_env/lib/python3.6/site-packages/gensim/models/base_any2vec.py in __init__(self, sentences, corpus_file, workers, vector_size, epochs, callbacks, batch_words, trim_rule, sg, alpha, window, seed, hs, negative, ns_exponent, cbow_mean, min_alpha, compute_loss, fast_version, **kwargs)
#     757                 raise TypeError("You can't pass a generator as the sentences argument. Try a sequence.")
#     758
# --> 759             self.build_vocab(sentences=sentences, corpus_file=corpus_file, trim_rule=trim_rule)
#     760             self.train(
#     761                 sentences=sentences, corpus_file=corpus_file, total_examples=self.corpus_count,
#
# ~/anaconda3/envs/snlp_env/lib/python3.6/site-packages/gensim/models/base_any2vec.py in build_vocab(self, sentences, corpus_file, update, progress_per, keep_raw_vocab, trim_rule, **kwargs)
#     934         """
#     935         total_words, corpus_count = self.vocabulary.scan_vocab(
# --> 936             sentences=sentences, corpus_file=corpus_file, progress_per=progress_per, trim_rule=trim_rule)
#     937         self.corpus_count = corpus_count
#     938         self.corpus_total_words = total_words
#
# ~/anaconda3/envs/snlp_env/lib/python3.6/site-packages/gensim/models/word2vec.py in scan_vocab(self, sentences, corpus_file, progress_per, workers, trim_rule)
#    1590             sentences = LineSentence(corpus_file)
#    1591
# -> 1592         total_words, corpus_count = self._scan_vocab(sentences, progress_per, trim_rule)
#    1593
#    1594         logger.info(
#
# ~/anaconda3/envs/snlp_env/lib/python3.6/site-packages/gensim/models/word2vec.py in _scan_vocab(self, sentences, progress_per, trim_rule)
#    1559         vocab = defaultdict(int)
#    1560         checked_string_types = 0
# -> 1561         for sentence_no, sentence in enumerate(sentences):
#    1562             if not checked_string_types:
#    1563                 if isinstance(sentence, string_types):
#
# <ipython-input-2-6192eb36a4e3> in __iter__(self, filename)
#      15             preprocessed = utils.simple_preprocess(line)
#      16             total_words += len(split)
# ---> 17             print("preprocessed",preprocessed)
#      18             yield preprocessed
#      19         #print("Total words:", total_words)
#
# ~/anaconda3/envs/snlp_env/lib/python3.6/site-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # newlines imply flush in subprocesses
#
# ~/anaconda3/envs/snlp_env/lib/python3.6/site-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~/anaconda3/envs/snlp_env/lib/python3.6/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/anaconda3/envs/snlp_env/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
#Params
window_size_list = [2,5,15] #[1?,5?,10? Based on Hist]
vector_size_list = [100,300,600] #[100,300,600]
noise_words_list = [2,5,20] #[2,5,20]
iters_list = [10, 20, 30]
vocab_restrics = [0, 10000, 30000]
#sample=?
sentences = TweetCorpus()
for a in window_size_list:
    for b in vector_size_list:
        for c in noise_words_list:
            for d in iters_list:
                model = gensim.models.Word2Vec(sentences=sentences, window=a, sample=0.00001, iter=d, size=b, min_count=1, sg=1, hs=0, negative=c)
                accuracy = model.wv.accuracy('questions-words.txt', restrict_vocab=10000)
                total = 0
                correct = 0
                for i in range(8):
                    #print(accuracy[i]['section'])
                    #print(len(accuracy[i]['correct']))
                    #print(len(accuracy[i]['incorrect']))
                    total += len(accuracy[i]['correct']) + len(accuracy[i]['incorrect'])
                    correct += len(accuracy[i]['correct'])
                accuracy = correct / total
                fname = "window_"+str(a)+"_size_"+str(b)+"_noise_"+str(c)+"_iters_"+str(d)+"_accuracy_"+str(accuracy)+".kv"
                print("Accuracy:", accuracy, "For:", fname)
                model.wv.save_word2vec_format(fname)

# %%
print(model.wv.most_similar(positive=['fashion'], topn=5))
from sklearn.decomposition import IncrementalPCA    # inital reduction
from sklearn.manifold import TSNE                   # final reduction
import numpy as np                                  # array handling


def reduce_dimensions(model):
    num_dimensions = 2  # final num dimensions (2D, 3D, etc)

    vectors = [] # positions in vector space
    labels = [] # keep track of words to label our data again later
    print("start iter")
    for word in model.wv.vocab:
        vectors.append(model.wv[word])
        labels.append(word)
    print("end iter")
    # convert both lists into numpy vectors for reduction
    vectors = np.asarray(vectors)
    labels = np.asarray(labels)

    # reduce using t-SNE
    vectors = np.asarray(vectors)
    print("start tsne")
    tsne = TSNE(n_components=num_dimensions, random_state=0)
    vectors = tsne.fit_transform(vectors)
    print("end tsne")

    x_vals = [v[0] for v in vectors]
    y_vals = [v[1] for v in vectors]
    return x_vals, y_vals, labels


x_vals, y_vals, labels = reduce_dimensions(model)


def plot_with_matplotlib(x_vals, y_vals, labels):
    print("Using matplotlib")
    import matplotlib.pyplot as plt
    import random

    random.seed(0)

    plt.figure(figsize=(12, 12))
    plt.scatter(x_vals, y_vals)

    #
    # Label randomly subsampled 25 data points
    #
    indices = list(range(len(labels)))
    selected_indices = random.sample(indices, 25)
    for i in selected_indices:
        plt.annotate(labels[i], (x_vals[i], y_vals[i]))

plot_function = plot_with_matplotlib


plot_function(x_vals, y_vals, labels)
